# %%
import pandas as pd 
import numpy as np
house_sales = "Resources/Perth_Housing_Prices2.csv"
sales_df = pd.read_csv(house_sales)
sales_df.set_index('ADDRESS', inplace=True)
sales_df.head()

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
sales_df['GARAGE'] = sales_df['GARAGE'].fillna(0)

# %%
sales_df.columns
# Out:
# Index(['SUBURB', 'PRICE', 'BEDROOMS', 'BATHROOMS', 'GARAGE', 'LAND_AREA',
#        'FLOOR_AREA', 'BUILD_YEAR', 'CBD_DIST', 'NEAREST_STN',
#        'NEAREST_STN_DIST', 'DATE_SOLD', 'POSTCODE', 'LATITUDE', 'LONGITUDE',
#        'NEAREST_SCH', 'NEAREST_SCH_DIST', 'NEAREST_SCH_RANK'],
#       dtype='object')

# %%
# column names for recombining dataframe
columns = ['SUBURB', 'PRICE', 'BEDROOMS', 'BATHROOMS', 'GARAGE', 'LAND_AREA',
       'FLOOR_AREA', 'BUILD_YEAR', 'CBD_DIST', 'NEAREST_STN',
       'NEAREST_STN_DIST', 'DATE_SOLD', 'POSTCODE', 'LATITUDE', 'LONGITUDE',
       'NEAREST_SCH', 'NEAREST_SCH_DIST', 'NEAREST_SCH_RANK', 'Prediction']

# %%
# create empty dataframe for recombining into
combined_df = pd.DataFrame(columns=columns)
combined_df
# Out:
# Empty DataFrame
# Columns: [SUBURB, PRICE, BEDROOMS, BATHROOMS, GARAGE, LAND_AREA, FLOOR_AREA, BUILD_YEAR, CBD_DIST, NEAREST_STN, NEAREST_STN_DIST, DATE_SOLD, POSTCODE, LATITUDE, LONGITUDE, NEAREST_SCH, NEAREST_SCH_DIST, NEAREST_SCH_RANK, Prediction]
# Index: []

# %%
pred_house_sell = {}
temp = {}

# loop on every suburb
for SUBURB in sales_df['SUBURB'].unique():
    # slice
    sales_slice = sales_df[sales_df['SUBURB'] == SUBURB]
    df = sales_slice.copy()

    # set X and y
    y = sales_slice['PRICE']
    X = sales_slice.drop(['SUBURB', 'PRICE', 'NEAREST_STN', 'DATE_SOLD', 'POSTCODE', 'LATITUDE', 'LONGITUDE', 'NEAREST_SCH', 'NEAREST_SCH_RANK', 'BUILD_YEAR', 'CBD_DIST', 'NEAREST_STN_DIST', 'NEAREST_SCH_DIST'], axis=1)
    
    # scale the data
    X_scaled = StandardScaler().fit_transform(X)

    # train, test, split
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y)

    #building linear regression model on training data
    model1= LinearRegression().fit(X_train, y_train)
    pred_house_sell[SUBURB] = model1.predict(X_test)
    
    # make prediction and add it to the sliced dataframe
    prediction = model1.predict(X_scaled)
    df['Prediction'] = prediction
   
    # rebuild full dataframe
    combined_df = pd.concat([combined_df, df], ignore_index=False)

    # print r2 score
    print('Accuracy Score:', r2_score(y_test, pred_house_sell[SUBURB]))  

    # build dictionary with all r2 scores
    temp[SUBURB] = r2_score(y_test, pred_house_sell[SUBURB])

# convert dictionary to dataframe
temp = pd.DataFrame.from_dict(temp, orient ='index').reset_index()
# Out:
# Accuracy Score: 0.6760870381452443
# Accuracy Score: 0.8080780135497013
# Accuracy Score: 0.5153912311264413
# Accuracy Score: -0.15912477142034498
# Accuracy Score: 0.003217128365855859
# Accuracy Score: 0.44879573220892466
# Accuracy Score: 0.12417706984956012
# Accuracy Score: 0.36660484190859843
# Accuracy Score: 0.3165853022628883
# Accuracy Score: 0.3716193973458475
# Accuracy Score: 0.6694598517673698
# Accuracy Score: 0.04831674263707675
# Accuracy Score: 0.7689068069785805
# Accuracy Score: 0.05813727595766971
# Accuracy Score: -1.5124193806874922
# Accuracy Score: -5.60566137897172
# Accuracy Score: 0.47608756277756814
# Accuracy Score: 0.002348991349801932
# Accuracy Score: -0.9193480503346565
# Accuracy Score: 0.2120012499629882
# Accuracy Score: 0.03389632143405319
# Accuracy Score: 0.21888988199317783
# Accuracy Score: 0.4402949096742812
# Accuracy Score: 0.06492188169174429
# Accuracy Score: 0.15677375590795195
# Accuracy Score: 0.4251987711542411
# Accuracy Score: 0.8697300204170408
# Accuracy Score: 0.5031078061115677
# Accuracy Score: -97.63599239830597
# Accuracy Score: 0.35982208283280803
# Accuracy Score: -0.46791677050368774
# Accuracy Score: 0.12473594657083997
# Accuracy Score: 0.7405687143619335
# Accuracy Score: 0.4578574238063644
# Accuracy Score: 0.7944849041184028
# Accuracy Score: -0.42224606463748215
# Accuracy Score: 0.1391949640212664
# Accuracy Score: 0.49751719941760897
# Accuracy Score: 0.6779612043110887
# Accuracy Score: 0.24618614480848866
# Accuracy Score: -36.853154410260366
# Accuracy Score: -0.16937687675389057
# Accuracy Score: 0.5054752947874857
# Accuracy Score: -9.081307426349422
# Accuracy Score: 0.47031076191636634
# Accuracy Score: -5.450016979865174
# Accuracy Score: 0.4878630466487509
# Accuracy Score: -0.25576862733945505
# Accuracy Score: -0.0575363867273162
# Accuracy Score: 0.6559689311816964
# Accuracy Score: -1.9845270255900207
# Accuracy Score: 0.5061128497327896
# Accuracy Score: -11.581598287060135
# Accuracy Score: 0.16140360584320224
# Accuracy Score: -0.2940677091540871
# Accuracy Score: -0.8565311310189998
# Accuracy Score: -1.4855835893477756
# Accuracy Score: -0.5146484397051383
# Accuracy Score: nan
# Accuracy Score: nan
# c:\Users\merov\anaconda3\envs\PythonData\lib\site-packages\sklearn\metrics\_regression.py:582: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\merov\anaconda3\envs\PythonData\lib\site-packages\sklearn\metrics\_regression.py:582: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\merov\anaconda3\envs\PythonData\lib\site-packages\sklearn\metrics\_regression.py:582: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)
# c:\Users\merov\anaconda3\envs\PythonData\lib\site-packages\sklearn\metrics\_regression.py:582: UndefinedMetricWarning: R^2 score is not well-defined with less than two samples.
#   warnings.warn(msg, UndefinedMetricWarning)

# %%
# rename columns for merging
temp.columns = ['SUBURB', 'r2 Score']
temp.head()
# Out:
#         SUBURB  r2 Score
# 0       Aveley  0.676087
# 1   Bibra Lake  0.808078
# 2     Ferndale  0.515391
# 3      Bedford -0.159125
# 4  Queens Park  0.003217

# %%
combined_df.head(2)
# Out:
#                         SUBURB   PRICE BEDROOMS BATHROOMS GARAGE LAND_AREA  \
# 9 Covenham Crescent     Aveley  430000        4         2      2       375
# 23 Semerwater Crescent  Aveley  358000        4         1      0       440
#
#                        FLOOR_AREA BUILD_YEAR CBD_DIST         NEAREST_STN  \
# 9 Covenham Crescent           160       2017    22400  Woodbridge Station
# 23 Semerwater Crescent        167       2016    22400     Midland Station
#
#                        NEAREST_STN_DIST  DATE_SOLD POSTCODE   LATITUDE  \
# 9 Covenham Crescent               11700  10-2020\r     6069 -31.786825
# 23 Semerwater Crescent            11400  06-2020\r     6069 -31.789123
#
#                          LONGITUDE                            NEAREST_SCH  \
# 9 Covenham Crescent     115.994063  SWAN VALLEY ANGLICAN COMMUNITY SCHOOL
# 23 Semerwater Crescent  116.000095  SWAN VALLEY ANGLICAN COMMUNITY SCHOOL
#
#                         NEAREST_SCH_DIST  NEAREST_SCH_RANK     Prediction
# 9 Covenham Crescent             1.167177              53.0  395079.114566
# 23 Semerwater Crescent          1.501317              53.0  374139.956622

# %%
# merge r2 Score onto recombined dataframe
sales_df_r2 = pd.merge(combined_df, temp, how='left', on=['SUBURB', 'SUBURB'])
sales_df_r2.head(2)
# Out:
#    SUBURB   PRICE BEDROOMS BATHROOMS GARAGE LAND_AREA FLOOR_AREA BUILD_YEAR  \
# 0  Aveley  430000        4         2      2       375        160       2017
# 1  Aveley  358000        4         1      0       440        167       2016
#
#   CBD_DIST         NEAREST_STN NEAREST_STN_DIST  DATE_SOLD POSTCODE  \
# 0    22400  Woodbridge Station            11700  10-2020\r     6069
# 1    22400     Midland Station            11400  06-2020\r     6069
#
#     LATITUDE   LONGITUDE                            NEAREST_SCH  \
# 0 -31.786825  115.994063  SWAN VALLEY ANGLICAN COMMUNITY SCHOOL
# 1 -31.789123  116.000095  SWAN VALLEY ANGLICAN COMMUNITY SCHOOL
#
#    NEAREST_SCH_DIST  NEAREST_SCH_RANK     Prediction  r2 Score
# 0          1.167177              53.0  395079.114566  0.676087
# 1          1.501317              53.0  374139.956622  0.676087

# %%
# remove nan's of r2 scores that didn't have enough data to calculate
sales_df_r2['r2 Score'] = sales_df_r2['r2 Score'].fillna(0)

# %%
sales_df_r2.tail()
# Out:
#        SUBURB   PRICE BEDROOMS BATHROOMS GARAGE LAND_AREA FLOOR_AREA  \
# 33646  Whitby  450000        4         2      2       510        208
# 33647  Whitby  440000        4         2      2       510        179
# 33648  Whitby  430000        4         2      2       480        187
# 33649  Treeby  580000        4         2      2       373        182
# 33650  Treeby  610000        4         2      2       428        276
#
#       BUILD_YEAR CBD_DIST               NEAREST_STN NEAREST_STN_DIST  \
# 33646       1940    38900          Armadale Station            14300
# 33647       1969    39000          Armadale Station            14300
# 33648       1965    39000          Armadale Station            14400
# 33649       2004    19800  Cockburn Central Station             1500
# 33650       2008    19300  Cockburn Central Station             1700
#
#        DATE_SOLD POSTCODE   LATITUDE   LONGITUDE           NEAREST_SCH  \
# 33646  01-2017\r     6123 -32.281773  115.997529  COURT GRAMMAR SCHOOL
# 33647  06-2017\r     6123 -32.281772  115.997709  COURT GRAMMAR SCHOOL
# 33648  06-2017\r     6123 -32.282182  115.997120  COURT GRAMMAR SCHOOL
# 33649  09-2019\r     6164 -32.129518  115.873926        ATWELL COLLEGE
# 33650  09-2019\r     6164 -32.124537  115.876416        ATWELL COLLEGE
#
#        NEAREST_SCH_DIST  NEAREST_SCH_RANK  Prediction  r2 Score
# 33646          1.470061               NaN    450000.0       0.0
# 33647          1.476795               NaN    440000.0       0.0
# 33648          1.497308               NaN    430000.0       0.0
# 33649          1.851464             129.0    580000.0       0.0
# 33650          2.449745             129.0    580000.0       0.0

# %%
# write csv to file
sales_df_r2.to_csv('Perth Housing Predictions and r2.csv', sep=',')
