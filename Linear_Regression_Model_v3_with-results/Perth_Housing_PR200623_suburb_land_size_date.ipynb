# %%
import pandas as pd 
import numpy as np
house_sales = "../Resources/Perth_Housing_Prices450_D.csv"
sales_450 = pd.read_csv(house_sales)
sales_450.set_index('ADDRESS', inplace=True)

house_sales2 = "../Resources/Perth_Housing_Prices1000_D.csv"
sales_1000 = pd.read_csv(house_sales2)
sales_1000.set_index('ADDRESS', inplace=True)

house_sales3 = "../Resources/Perth_Housing_Prices_plus_D.csv"
sales_plus = pd.read_csv(house_sales3)
sales_plus.set_index('ADDRESS', inplace=True)

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# column names for recombining dataframe
columns = ['SUBURB', 'PRICE', 'BEDROOMS', 'BATHROOMS', 'GARAGE', 'LAND_AREA',
       'FLOOR_AREA', 'BUILD_YEAR', 'CBD_DIST', 'NEAREST_STN',
       'NEAREST_STN_DIST', 'DATE_SOLD', 'POSTCODE', 'LATITUDE', 'LONGITUDE',
       'NEAREST_SCH', 'NEAREST_SCH_DIST', 'NEAREST_SCH_RANK', 'Prediction']

# %%
# create empty dataframe for recombining into
combined_df = pd.DataFrame(columns=columns)
combined_df
# Out:
# Empty DataFrame
# Columns: [SUBURB, PRICE, BEDROOMS, BATHROOMS, GARAGE, LAND_AREA, FLOOR_AREA, BUILD_YEAR, CBD_DIST, NEAREST_STN, NEAREST_STN_DIST, DATE_SOLD, POSTCODE, LATITUDE, LONGITUDE, NEAREST_SCH, NEAREST_SCH_DIST, NEAREST_SCH_RANK, Prediction]
# Index: []

# %%
# linear regression model with dataframe broken down by suburb and only properties with
# land area less than 450m2 analysed.


pred_house_sell = {}


# loop on every suburb
for SUBURB in sales_450['SUBURB'].unique():
    # slice
    sales_slice = sales_450[sales_450['SUBURB'] == SUBURB]
    sales_slice = sales_slice[sales_slice['LAND_AREA'] < 450]
    df = sales_slice.copy()

    # set X and y
    y = sales_slice['PRICE']
    X = sales_slice.drop(['SUBURB', 'PRICE', 'NEAREST_STN', 'DATE_SOLD', 'POSTCODE', 'LATITUDE', 'LONGITUDE', 
                          'NEAREST_SCH', 'NEAREST_SCH_RANK'], axis=1)
    
    # scale the data
    X_scaled = StandardScaler().fit_transform(X)

    # train, test, split
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y)

    #building linear regression model on training data
    model1 = LinearRegression().fit(X_train, y_train)
    pred_house_sell[SUBURB] = model1.predict(X_test)
    
    # make prediction and add it to the sliced dataframe
    prediction = model1.predict(X_scaled)
    df['Prediction'] = prediction
   
    # rebuild full dataframe
    combined_df = pd.concat([combined_df, df], ignore_index=False)

    # print r2 score
    print('Accuracy Score:', SUBURB, r2_score(y_test, pred_house_sell[SUBURB]))
# Out:
# Accuracy Score: Butler 0.23191025603633364
# Accuracy Score: Alkimos 0.11616288526644292
# Accuracy Score: Banksia Grove 0.71584611122515
# Accuracy Score: Pearsall -0.8501845981838048
# Accuracy Score: Harrisdale -0.17257155092719745
# Accuracy Score: Shenton Park 0.6020106795352951
# Accuracy Score: Bertram -0.7274736360347616
# Accuracy Score: Aveley 0.5518728448445402
# Accuracy Score: Redcliffe -1.2854320403579385
# Accuracy Score: North Fremantle -0.2524160499873027
# Accuracy Score: Queens Park 0.4718840818094563
# Accuracy Score: Eglinton 0.1114513895245155
# Accuracy Score: West Leederville 0.6857471685708383
# Accuracy Score: Inglewood 0.7323165118177912
# Accuracy Score: Clarkson -0.8215015698079655
# Accuracy Score: South Fremantle 0.5012635895443157
# Accuracy Score: Wandi -1.309577734153168
# Accuracy Score: Innaloo 0.1821724654098189
# Accuracy Score: Ascot 0.35499311965182934
# Accuracy Score: Joondanna 0.4702659611593113
# Accuracy Score: Ridgewood 0.10320736828309773
# Accuracy Score: Cannington -0.31815217736064505
# Accuracy Score: Beaconsfield -14.632542745840423
# Accuracy Score: Mount Claremont 0.39694848166476904
# Accuracy Score: Subiaco 0.9113630504881278
# Accuracy Score: Bentley 0.39195061076690774
# Accuracy Score: Dayton 0.5997422439585878
# Accuracy Score: Fremantle 0.6422461713301812
# Accuracy Score: Yanchep -0.25543790620366935
# Accuracy Score: Doubleview 0.3191437755461296
# Accuracy Score: Embleton 0.46917959311406465
# Accuracy Score: East Victoria Park 0.7028064687328182
# Accuracy Score: North Perth -0.29013393852994973
# Accuracy Score: Ellenbrook -0.007766707229634573
# Accuracy Score: Churchlands -0.0756252450018835
# Accuracy Score: Swanbourne 0.11642814444156213
# Accuracy Score: Stirling 0.45518787051759313
# Accuracy Score: Brentwood -0.4202674211103228
# Accuracy Score: White Gum Valley 0.07853290297059046
# Accuracy Score: Ardross 0.373521454487168
# Accuracy Score: Madeley 0.5030550320040761
# Accuracy Score: Mount Hawthorn -3.5917141584031276
# Accuracy Score: East Cannington 0.12551746541454245
# Accuracy Score: Jindalee 0.7117392288305358
# Accuracy Score: Carlisle -0.2731042477131427
# Accuracy Score: Yokine 0.6780687466308434
# Accuracy Score: Karrinyup 0.3874583786085135
# Accuracy Score: Sinagra -4.669083842276042
# Accuracy Score: North Beach -0.13659574844801003
# Accuracy Score: Darch 0.3438586023593604
# Accuracy Score: Maylands 0.7505467096305293
# Accuracy Score: Brabham 0.3549340394413387
# Accuracy Score: Victoria Park 0.5080557289675864
# Accuracy Score: Claremont 0.6227195924866487
# Accuracy Score: Scarborough -6.490823409150908
# Accuracy Score: Hilbert -0.3156016793282128
# Accuracy Score: Gwelup 0.7653215801610671
# Accuracy Score: Aubin Grove -0.16474915913374266
# Accuracy Score: Caversham -0.3281620882794709
# Accuracy Score: Atwell -0.49248545837275515
# Accuracy Score: Kewdale 0.8007404386986033
# Accuracy Score: Mosman Park 0.05019233206218998
# Accuracy Score: Mindarie 0.5374870820336999
# Accuracy Score: Piara Waters -0.8722478715308981
# Accuracy Score: Alfred Cove 0.2516828460222531
# Accuracy Score: North Coogee -0.0026808909689579608
# Accuracy Score: Melville 0.8089673614192614
# Accuracy Score: Currambine 0.7765492194031607
# Accuracy Score: Bayswater -1.5921282147640787
# Accuracy Score: Lockridge 0.06407052317298834
# Accuracy Score: Riverton 0.7272278646948005
# Accuracy Score: Balga -2.0120627933142043
# Accuracy Score: Wellard -9.277250533883183
# Accuracy Score: Bedford 0.8177505532007356
# Accuracy Score: Joondalup -0.019503615967508603
# Accuracy Score: Balcatta 0.8062445065808161
# Accuracy Score: Mount Pleasant -0.11392420173302975
# Accuracy Score: Nollamara 0.7192030936804221
# Accuracy Score: Myaree 0.6143802027823787
# Accuracy Score: Stratton -3.6724445625499182
# Accuracy Score: Tuart Hill -0.015026378497150272
# Accuracy Score: East Fremantle -1.1439909566473472
# Accuracy Score: South Guildford -5.670465075762805
# Accuracy Score: Wattle Grove -0.4094223629144145
# Accuracy Score: St James 0.8504506887372397
# Accuracy Score: Belmont 0.9133738445666415
# Accuracy Score: Landsdale -0.364224142397648
# Accuracy Score: Highgate -2.0904809062787693
# Accuracy Score: Osborne Park 0.6064681080885557
# Accuracy Score: Cottesloe -0.6123786686931407
# Accuracy Score: Mount Lawley -1.4931191003522057
# Accuracy Score: Bassendean -1.1954194752090785
# Accuracy Score: Hilton -0.9155808981851301
# Accuracy Score: Wilson 0.10546299235359236
# Accuracy Score: Iluka 0.614775336173476
# Accuracy Score: Beeliar -1.376552684952991
# Accuracy Score: Palmyra -0.5131195994817621
# Accuracy Score: Kensington 0.20801550607004005
# Accuracy Score: Ashby -0.17150830743334589
# Accuracy Score: Burswood 0.7097316997288555
# Accuracy Score: Westminster 0.7364553684591588
# Accuracy Score: Guildford -1.0724380285160038
# Accuracy Score: Golden Bay -0.8923682069317525
# Accuracy Score: Southern River 0.8529371785311628
# Accuracy Score: Spearwood 0.7048473629228236
# Accuracy Score: Byford -12.84238819249378
# Accuracy Score: Lynwood -23.65612633839847
# Accuracy Score: Coogee -0.8126133334877563
# Accuracy Score: Coolbellup -5.531123491793086
# Accuracy Score: Manning -4.1376976383557
# Accuracy Score: Bibra Lake -1.388426023059242
# Accuracy Score: Shoalwater -0.35018594880640164
# Accuracy Score: Cloverdale -1.1706210652555322
# Accuracy Score: Hillarys 0.2336191303610271
# Accuracy Score: Baldivis -0.20844220456538753
# Accuracy Score: Woodlands -5.897571020882194
# Accuracy Score: Willagee -0.9550947343045539
# Accuracy Score: Hamilton Hill -2.645496884676316
# Accuracy Score: Morley 0.3267149349698222
# Accuracy Score: Champion Lakes -0.33495994997193823
# Accuracy Score: Midland -0.35262803495008277
# Accuracy Score: Hammond Park 0.4489051741473933
# Accuracy Score: Attadale 0.3651933773416435
# Accuracy Score: The Vines 0.8029179855476024
# Accuracy Score: Kelmscott -0.11209916437691292
# Accuracy Score: West Perth 0.6153821618710302
# Accuracy Score: Secret Harbour -5.455724526859085
# Accuracy Score: Wembley 0.6535634481671287
# Accuracy Score: Kenwick -2.826877594760185
# Accuracy Score: Wembley Downs -57.32302399232305
# Accuracy Score: Applecross 0.7280433738268023
# Accuracy Score: Como -0.7235156582078182
# Accuracy Score: Lathlain -49.993089055688515
# Accuracy Score: Shelley -1721.3958962476731
# Accuracy Score: Tapping -2.061718456925072
# Accuracy Score: Bicton -59.47782943431662
# Accuracy Score: Maddington 0.16844624939692765
# Accuracy Score: South Perth 0.3598790303305056
# Accuracy Score: Rockingham -16.930049326970458
# Accuracy Score: Canning Vale 0.8172079287454738
# Accuracy Score: Helena Valley -0.1688531491779599
# Accuracy Score: South Lake -767.2837694189225
# Accuracy Score: Kallaroo -61.046617389261556
# Accuracy Score: Leederville -4.599617465367256
# Accuracy Score: Rivervale -12.571043033882194
# Accuracy Score: Connolly -301.5683438136887
# Accuracy Score: Mirrabooka -7.552817577196867
# Accuracy Score: Brookdale 0.3855643548189681
# Accuracy Score: Crawley -4.2439845447073665
# Accuracy Score: City Beach 0.43032584322353484
# Accuracy Score: Ballajura -0.8570800560484557
# Accuracy Score: Trigg -2250.7861931806733
# Accuracy Score: Langford -741.0590243942007
# Accuracy Score: Salter Point -2.9116289507310205
# Accuracy Score: Orelia -122.95810906270977
# Accuracy Score: Booragoon -2.2782410973004583
# Accuracy Score: Waikiki -10.442962931281015
# Accuracy Score: Success -7.728772029590644
# Accuracy Score: Dianella -28.86972723450383
# Accuracy Score: Watermans Bay 0.8118245182741914
# Accuracy Score: Murdoch -10.373874702565113
# Accuracy Score: Burns Beach -1.5967366946897275
# Accuracy Score: Gosnells -23.99729737945166
# Accuracy Score: Armadale -1.3504347385927802
# Accuracy Score: Jandakot 0.05821154986800292
# Accuracy Score: Singleton -600.7760169369933
# Accuracy Score: Eden Hill -0.5912386309023547
# Accuracy Score: Girrawheen -13.491983268398178
# Accuracy Score: Hocking -24.26029456661114
# Accuracy Score: Yangebup -0.8931320582146045
# Accuracy Score: Carramar -1.3924865124456258
# Accuracy Score: Floreat 0.7255499140199639
# Accuracy Score: Quinns Rocks -0.3773880357754602
# Accuracy Score: Mount Nasura 0.184260740825675
# Accuracy Score: Maida Vale -1384.8066788236472
# Accuracy Score: Bennett Springs -31.100833099615187
# Accuracy Score: Parkwood 0.763352613526232
# Accuracy Score: Seville Grove -1.963998154116867
# Accuracy Score: High Wycombe -12.957631814900067
# Accuracy Score: Forrestfield -5.275277708103466
# Accuracy Score: Henley Brook 0.21400804245814176
# Accuracy Score: Waterford -8.430028990552175
# Accuracy Score: Daglish 0.7516842590711617
# Accuracy Score: Middle Swan -3.0253028456677873
# Accuracy Score: Woodbridge -0.8545198910008391
# Accuracy Score: Karnup -592.7172854376587
# Accuracy Score: Kwinana Town Centre -86.90723697505834
# Accuracy Score: Nedlands -0.20843983476488792
# Accuracy Score: Kardinya -0.3856153754242382
# Accuracy Score: Port Kennedy -58.20573240296331

# %%
# linear regression model with dataframe broken down by suburb and only properties with
# land area 450m2 to less than 1000m2 analysed.


pred_house_sell = {}


# loop on every suburb
for SUBURB in sales_1000['SUBURB'].unique():
    # slice
    sales_slice = sales_1000[sales_1000['SUBURB'] == SUBURB]
    sales_slice = sales_slice[(sales_slice['LAND_AREA'] > 449) & (sales_slice['LAND_AREA'] < 1000)]
    df = sales_slice.copy()

    # set X and y
    y = sales_slice['PRICE']
    X = sales_slice.drop(['SUBURB', 'PRICE', 'NEAREST_STN', 'DATE_SOLD', 'POSTCODE', 'LATITUDE', 'LONGITUDE', 
                          'NEAREST_SCH', 'NEAREST_SCH_RANK'], axis=1)
    
    # scale the data
    X_scaled = StandardScaler().fit_transform(X)

    # train, test, split
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y)

    #building linear regression model on training data
    model2 = LinearRegression().fit(X_train, y_train)
    pred_house_sell[SUBURB] = model2.predict(X_test)
    
    # make prediction and add it to the sliced dataframe
    prediction = model2.predict(X_scaled)
    df['Prediction'] = prediction
   
    # rebuild full dataframe
    combined_df = pd.concat([combined_df, df], ignore_index=False)

    # print r2 score
    print('Accuracy Score:', SUBURB, r2_score(y_test, pred_house_sell[SUBURB]))
# Out:
# Accuracy Score: Merriwa 0.005130461113675544
# Accuracy Score: Carramar 0.5317142597306166
# Accuracy Score: Iluka 0.6420652883034017
# Accuracy Score: Jane Brook 0.25535190827953735
# Accuracy Score: Tapping 0.4463518265607016
# Accuracy Score: Huntingdale 0.3167497168332005
# Accuracy Score: Port Kennedy 0.6309119305761374
# Accuracy Score: Bertram 0.3835392540583019
# Accuracy Score: Secret Harbour 0.7894131847954111
# Accuracy Score: Hocking 0.3440035129635136
# Accuracy Score: Mindarie 0.61031330541179
# Accuracy Score: Darch 0.4037895910629218
# Accuracy Score: Atwell 0.7316306549238394
# Accuracy Score: Wattle Grove 0.3044835528191302
# Accuracy Score: Bennett Springs 0.20702945670174133
# Accuracy Score: Gwelup 0.5483942936247828
# Accuracy Score: High Wycombe 0.6815831973520532
# Accuracy Score: Currambine 0.27425891984446227
# Accuracy Score: Quinns Rocks 0.8164437437801837
# Accuracy Score: Singleton 0.45162243051373563
# Accuracy Score: Kinross 0.4288855825362633
# Accuracy Score: Warnbro 0.5999609272260409
# Accuracy Score: Canning Vale 0.5206192127182371
# Accuracy Score: South Lake 0.2716123463592134
# Accuracy Score: South Guildford 0.6854538063318696
# Accuracy Score: Beeliar 0.5832941764851858
# Accuracy Score: Landsdale 0.24451208306431882
# Accuracy Score: Beldon 0.3651663756011029
# Accuracy Score: Aubin Grove 0.42475279932211996
# Accuracy Score: Orelia -0.22566060741900507
# Accuracy Score: Ridgewood -0.6745856677086488
# Accuracy Score: Mullaloo 0.5608229303733892
# Accuracy Score: Madeley 0.3326538193889017
# Accuracy Score: Mirrabooka -0.10994781400462816
# Accuracy Score: Cooloongup -0.031510857002602366
# Accuracy Score: Waikiki 0.6165094336204445
# Accuracy Score: Heathridge 0.39307610143596605
# Accuracy Score: Alexander Heights 0.3875085442848011
# Accuracy Score: Manning 0.6088448588069693
# Accuracy Score: Ballajura 0.6419735197003948
# Accuracy Score: Burns Beach 0.5382784795131941
# Accuracy Score: Yangebup 0.6045352174242211
# Accuracy Score: Butler 0.43407451322785917
# Accuracy Score: Hillarys 0.7817790211228837
# Accuracy Score: Clarkson 0.7415008585698553
# Accuracy Score: Hamersley 0.36958534577978397
# Accuracy Score: Kallaroo 0.6659532018523068
# Accuracy Score: Wanneroo 0.7948926087727379
# Accuracy Score: Camillo -0.08164603726164943
# Accuracy Score: Carine 0.596818132593897
# Accuracy Score: Kenwick -0.3090115870590462
# Accuracy Score: City Beach -0.003408560029873442
# Accuracy Score: Marangaroo -0.407431993005144
# Accuracy Score: Southern River 0.7274869395716632
# Accuracy Score: Parmelia 0.18301836042909847
# Accuracy Score: Bibra Lake 0.5809859240641022
# Accuracy Score: Seville Grove -0.9388814012951316
# Accuracy Score: Edgewater 0.26260081701717
# Accuracy Score: Ellenbrook 0.4804927153611145
# Accuracy Score: Langford -0.23529897140088174
# Accuracy Score: Maida Vale 0.4438168060756945
# Accuracy Score: Warwick 0.6135391724087702
# Accuracy Score: Caversham 0.38800671430381406
# Accuracy Score: Coogee 0.7448224272757913
# Accuracy Score: Greenwood 0.4064978258724805
# Accuracy Score: Stratton -0.0014463071837880204
# Accuracy Score: Kensington 0.42703239164884677
# Accuracy Score: Floreat 0.6680607847446912
# Accuracy Score: Stirling 0.6612064732755141
# Accuracy Score: Success 0.029100968770813807
# Accuracy Score: Forrestfield 0.6921239982873869
# Accuracy Score: Ocean Reef 0.6896374546324995
# Accuracy Score: Banksia Grove 0.6152545703204688
# Accuracy Score: Ferndale -0.20203773148770376
# Accuracy Score: Beechboro 0.6718490139215711
# Accuracy Score: Safety Bay 0.3283204263404981
# Accuracy Score: Leeming 0.46569096872665827
# Accuracy Score: Parkwood -0.009714331497768569
# Accuracy Score: Sorrento 0.7596064586290598
# Accuracy Score: Sinagra 0.18032495759795097
# Accuracy Score: Ashby -0.23949282840391328
# Accuracy Score: Jandakot 0.5872830370021747
# Accuracy Score: Noranda 0.13064281929698773
# Accuracy Score: Padbury 0.2205294395729075
# Accuracy Score: Woodvale 0.6784017455210081
# Accuracy Score: Thornlie 0.6476528078383343
# Accuracy Score: Medina 0.48833673655548493
# Accuracy Score: Aveley 0.4870783816835529
# Accuracy Score: Wembley Downs 0.17739717977101366
# Accuracy Score: Koondoola -0.35841398256686885
# Accuracy Score: Duncraig 0.45595531294370106
# Accuracy Score: Trigg 0.6158383000999026
# Accuracy Score: Connolly 0.39610168340378227
# Accuracy Score: Harrisdale 0.7310259975828819
# Accuracy Score: Hammond Park 0.6641413655993998
# Accuracy Score: Redcliffe -0.019701272859489194
# Accuracy Score: Byford 0.5107161974164873
# Accuracy Score: Craigie -0.831223652185306
# Accuracy Score: Pearsall 0.21929538965973905
# Accuracy Score: Baldivis 0.3366381294098364
# Accuracy Score: Kingsley 0.6199112109609706
# Accuracy Score: Karrinyup 0.5387592863360121
# Accuracy Score: Bull Creek 0.7134694763389426
# Accuracy Score: Winthrop -1.2212514344499863
# Accuracy Score: Ardross 0.027131666177382274
# Accuracy Score: Attadale 0.5102499598188746
# Accuracy Score: Salter Point 0.317101780612438
# Accuracy Score: Girrawheen -0.23254826335876277
# Accuracy Score: Bateman 0.4604312768140534
# Accuracy Score: Churchlands 0.21563619452265015
# Accuracy Score: The Vines 0.08292285681618927
# Accuracy Score: Willagee 0.33541055736076164
# Accuracy Score: Piara Waters 0.6608438557002838
# Accuracy Score: Helena Valley 0.5048408054417157
# Accuracy Score: Booragoon 0.37136791073840414
# Accuracy Score: Lynwood -1.1918256656281212
# Accuracy Score: Jindalee 0.5300794881723137
# Accuracy Score: Mount Pleasant 0.10233857023724935
# Accuracy Score: Melville 0.6119429703038639
# Accuracy Score: Gosnells 0.514516923269522
# Accuracy Score: Yanchep 0.6292312150458066
# Accuracy Score: Joondalup 0.6313139055459017
# Accuracy Score: Coolbellup 0.3576092117281099
# Accuracy Score: Swan View 0.7175506132129559
# Accuracy Score: Swanbourne 0.30370174662209304
# Accuracy Score: Shoalwater 0.46793273301627447
# Accuracy Score: Woodlands -6.7376781748013
# Accuracy Score: Mount Hawthorn 0.7305000977803606
# Accuracy Score: Two Rocks 0.2145686639903156
# Accuracy Score: Rossmoyne 0.47504279942935734
# Accuracy Score: Nedlands 0.6472375770294494
# Accuracy Score: Mount Claremont 0.7528978949668073
# Accuracy Score: Lockridge -1.6242290071768735
# Accuracy Score: Mosman Park 0.2951504001489246
# Accuracy Score: Riverton -0.16630216762186834
# Accuracy Score: Hilton 0.456170352567155
# Accuracy Score: Henley Brook 0.09349244197574202
# Accuracy Score: Alfred Cove 0.45788587205900755
# Accuracy Score: Maddington 0.6083289406303947
# Accuracy Score: Eden Hill 0.3606886013046048
# Accuracy Score: Dianella 0.6404438298771433
# Accuracy Score: Rockingham 0.581240814263535
# Accuracy Score: Willetton 0.6928875189306407
# Accuracy Score: Beaconsfield 0.48839975925570345
# Accuracy Score: Kelmscott 0.6554972811039924
# Accuracy Score: Guildford 0.7343311263384354
# Accuracy Score: Brookdale -0.0844231669842046
# Accuracy Score: St James -1.415358891981021
# Accuracy Score: Leda 0.4662694775501378
# Accuracy Score: Hillman 0.358501308286284
# Accuracy Score: Inglewood 0.39397743046443345
# Accuracy Score: Kardinya 0.48483315924218184
# Accuracy Score: Embleton -0.41571697579862477
# Accuracy Score: Bedford 0.31965580402235894
# Accuracy Score: Hamilton Hill -0.15489931287695802
# Accuracy Score: Waterford 0.13840648607740846
# Accuracy Score: Beckenham -1.2572302267011177
# Accuracy Score: East Fremantle 0.46368835347990855
# Accuracy Score: Doubleview 0.17990461584328776
# Accuracy Score: East Cannington 0.32547783840601985
# Accuracy Score: Bayswater -2.9193698359596785
# Accuracy Score: Kiara -0.5139043827857368
# Accuracy Score: Bassendean -0.19176233393877684
# Accuracy Score: Marmion 0.4188566798930323
# Accuracy Score: North Beach 0.7999113305254467
# Accuracy Score: Middle Swan -0.5491768413370648
# Accuracy Score: Spearwood -0.1628980917671632
# Accuracy Score: Golden Bay 0.58530070050986
# Accuracy Score: Alkimos 0.18455389735453387
# Accuracy Score: Rivervale 0.07487555999126905
# Accuracy Score: Samson -0.17270897785768113
# Accuracy Score: Kewdale 0.4991259137489906
# Accuracy Score: Bicton 0.7967328929660072
# Accuracy Score: Armadale -7.311082376516589
# Accuracy Score: Wembley 0.34646942843259454
# Accuracy Score: Bullsbrook -0.10372851460241495
# Accuracy Score: White Gum Valley 0.41382650904587825
# Accuracy Score: Cloverdale 0.34149507881490315
# Accuracy Score: Belmont -8.760481652010132
# Accuracy Score: Menora 0.40516540337693063
# Accuracy Score: Bellevue -0.3666003145893917
# Accuracy Score: Shenton Park 0.6967251062989076
# Accuracy Score: East Victoria Park 0.5690773439136474
# Accuracy Score: Myaree 0.36282464698028294
# Accuracy Score: Wilson 0.43662299622444967
# Accuracy Score: Palmyra -0.8193522308496148
# Accuracy Score: Morley 0.5128357363856371
# Accuracy Score: Shelley 0.4229383093060417
# Accuracy Score: Karawara 0.3995079307546675
# Accuracy Score: Mount Lawley 0.053649586579699426
# Accuracy Score: Applecross 0.6653175099253763
# Accuracy Score: Queens Park -0.2973009680730587
# Accuracy Score: Ashfield -1.5931414691132963
# Accuracy Score: Cottesloe 0.07074356883374477
# Accuracy Score: Mount Nasura 0.4980250930742779
# Accuracy Score: Calista -0.9346047006115914
# Accuracy Score: Wellard -1.1288277555038424
# Accuracy Score: Coolbinia 0.38480782979989814
# Accuracy Score: South Fremantle 0.7965092239835517
# Accuracy Score: North Lake -2.3838640978383134
# Accuracy Score: Lathlain -1.4572441008468475
# Accuracy Score: Carlisle 0.08831369291643498
# Accuracy Score: Balcatta 0.6735498469517853
# Accuracy Score: Greenmount 0.6442693794736781
# Accuracy Score: Joondanna -0.22415409281879506
# Accuracy Score: North Perth -3.3049662323947
# Accuracy Score: Brentwood 0.7444239288320511
# Accuracy Score: Balga -0.04740328753635614
# Accuracy Score: Koongamia -0.6100797335366106
# Accuracy Score: Como -0.2915895919460667
# Accuracy Score: Murdoch 0.3571465166301623
# Accuracy Score: Dayton -2.748592246686008
# Accuracy Score: Midland -1.34105849828582
# Accuracy Score: West Leederville -2.3483206425180745
# Accuracy Score: Ascot 0.5916437778429968
# Accuracy Score: Bentley -1.1150824444364256
# Accuracy Score: Claremont -0.14367464502599248
# Accuracy Score: Midvale -1.5830502439898155
# Accuracy Score: Brabham -0.055958004733368316
# Accuracy Score: Westminster 0.44097866529388696
# Accuracy Score: South Perth 0.27618053442377366
# Accuracy Score: Watermans Bay -3.013261311311382
# Accuracy Score: Daglish -0.5644958502339357
# Accuracy Score: Maylands 0.23353947975135125
# Accuracy Score: Dalkeith -8.465242920857028
# Accuracy Score: Fremantle 0.4532603669345926
# Accuracy Score: Jolimont -3.131054910422451
# Accuracy Score: Mundijong 0.39500687794474143
# Accuracy Score: Wandi -37.90156504761813
# Accuracy Score: Woodbridge -1.7331401399628752
# Accuracy Score: Cannington -11.36882056620962
# Accuracy Score: Mount Richon -0.3057115098355352
# Accuracy Score: Hilbert -172.8943389823339
# Accuracy Score: Eglinton -102.30878989321194
# Accuracy Score: Yokine -1.014463349299867
# Accuracy Score: Victoria Park -2.6111150165431396
# Accuracy Score: Viveash 0.16855440726778348
# Accuracy Score: Lesmurdie -19.00505150943348
# Accuracy Score: Scarborough -0.4284975646807785
# Accuracy Score: North Coogee -44.427634165951694
# Accuracy Score: Cockburn Central -7.023752070491463
# Accuracy Score: Subiaco 0.5330353032744952
# Accuracy Score: North Fremantle -8788.507200246773
# Accuracy Score: Nollamara 0.28305513513322256
# Accuracy Score: Herne Hill 0.4557462076960037
# Accuracy Score: Tuart Hill 0.7265631358892606
# Accuracy Score: Innaloo 0.9393496765809093
# Accuracy Score: Burswood -0.700691819665965
# Accuracy Score: Champion Lakes -2.7414585251904726
# Accuracy Score: Karnup -0.2784550456785282
# Accuracy Score: Jarrahdale -0.6366258909230742
# Accuracy Score: Peppermint Grove 0.5299848713342239
# Accuracy Score: Kalamunda -0.5441758923999567

# %%
# linear regression model with dataframe broken down by suburb and only properties with
# land area 1000m2 or greater analysed.


pred_house_sell = {}


# loop on every suburb
for SUBURB in sales_plus['SUBURB'].unique():
    # slice
    sales_slice = sales_plus[sales_plus['SUBURB'] == SUBURB]
    sales_slice = sales_slice[sales_slice['LAND_AREA'] > 999]
    df = sales_slice.copy()

    # set X and y
    y = sales_slice['PRICE']
    X = sales_slice.drop(['SUBURB', 'PRICE', 'NEAREST_STN', 'DATE_SOLD', 'POSTCODE', 'LATITUDE', 'LONGITUDE', 
                          'NEAREST_SCH', 'NEAREST_SCH_RANK'], axis=1)
    
    # scale the data
    X_scaled = StandardScaler().fit_transform(X)

    # train, test, split
    X_train, X_test, y_train, y_test = train_test_split(X_scaled, y)

    #building linear regression model on training data
    model3 = LinearRegression().fit(X_train, y_train)
    pred_house_sell[SUBURB] = model3.predict(X_test)
    
    # make prediction and add it to the sliced dataframe
    prediction = model3.predict(X_scaled)
    df['Prediction'] = prediction
   
    # rebuild full dataframe
    combined_df = pd.concat([combined_df, df], ignore_index=False)

    # print r2 score
    print('Accuracy Score:', SUBURB, r2_score(y_test, pred_house_sell[SUBURB]))
# Out:
# Accuracy Score: Darlington 0.012426651982863302
# Accuracy Score: Roleystone 0.408755984259059
# Accuracy Score: Mount Helena 0.4483366636369638
# Accuracy Score: Lesmurdie 0.5409849060837155
# Accuracy Score: Gooseberry Hill 0.10430902059348168
# Accuracy Score: Mundaring 0.4004608312078748
# Accuracy Score: Bedfordale 0.04159060059356812
# Accuracy Score: Stoneville 0.5440444594183798
# Accuracy Score: Kalamunda -0.11923571178115111
# Accuracy Score: Glen Forrest 0.6632596799479318
# Accuracy Score: Helena Valley 0.5971346311116772
# Accuracy Score: The Vines -0.04785549481258444
# Accuracy Score: Parkerville 0.6778272909650508
# Accuracy Score: Maida Vale 0.6125099455766441
# Accuracy Score: Serpentine 0.38033947727636386
# Accuracy Score: Gidgegannup 0.5276788192208878
# Accuracy Score: Greenmount 0.009307570578659052
# Accuracy Score: Bullsbrook -16.948544274371528
# Accuracy Score: Oakford -0.694246751044928
# Accuracy Score: Dalkeith 0.11512303537871726
# Accuracy Score: Mount Richon 0.7698654298117392
# Accuracy Score: Mount Nasura 0.6759059583288307
# Accuracy Score: Chidlow 0.41758982003813183
# Accuracy Score: Jarrahdale 0.7400058105261176
# Accuracy Score: Kelmscott 0.845316264168548
# Accuracy Score: City Beach -0.030951201452570354
# Accuracy Score: Nedlands -0.7136201049515274
# Accuracy Score: Darling Downs -1.523049519297706
# Accuracy Score: Boya 0.2855686666013545
# Accuracy Score: Cardup 0.5947332307039248
# Accuracy Score: Henley Brook -0.372942111843205
# Accuracy Score: Sawyers Valley -0.4428591616014588
# Accuracy Score: Wellard -2.120192001310425
# Accuracy Score: Brigadoon -1.6461353811925674
# Accuracy Score: Banjup -0.6853607401818731
# Accuracy Score: East Cannington -0.4565532125052254
# Accuracy Score: Mount Claremont 0.08512688897717335
# Accuracy Score: Swan View 0.059180451902289044
# Accuracy Score: Applecross -2.2676487788764343
# Accuracy Score: Hilbert -215.45883791677758
# Accuracy Score: Mahogany Creek -3.979211645226404
# Accuracy Score: Palmyra -1.49244565415077
# Accuracy Score: Martin -0.46584692402925754
# Accuracy Score: Hovea -21.969150767610998
# Accuracy Score: Kenwick -1.6848197602726378
# Accuracy Score: East Fremantle 0.4164493791908038
# Accuracy Score: Alfred Cove -7.419934063644183
# Accuracy Score: Bassendean 0.34131195322463503
# Accuracy Score: Mundijong -0.9457280960451775
# Accuracy Score: Gnangara 0.6842953105400742
# Accuracy Score: Wanneroo -0.018312956294043836
# Accuracy Score: Attadale 0.2040124597371641
# Accuracy Score: Cannington -1.346054992990025
# Accuracy Score: Mariginiup -8.429209525614437
# Accuracy Score: Ferndale -6.810749201430305
# Accuracy Score: Byford -40.33192272820635
# Accuracy Score: Shoalwater -0.574527228414458
# Accuracy Score: Ascot -15.772554933911817
# Accuracy Score: Churchlands -14.530007993791108
# Accuracy Score: Two Rocks -7.740434261742461
# Accuracy Score: Guildford -1.9210279816501186
# Accuracy Score: Bicton -0.1837019025115818
# Accuracy Score: Como -1.8884340997350688
# Accuracy Score: Midland -5.678500618158437
# Accuracy Score: Watermans Bay -3.340605699446453
# Accuracy Score: Herne Hill -1.2055933588769414
# Accuracy Score: Rockingham -0.43899406763375226
# Accuracy Score: Osborne Park -38.760106569931615
# Accuracy Score: Wooroloo -2.3594126443440424
# Accuracy Score: Kallaroo -1.137496621710555
# Accuracy Score: Floreat -13.494290539149647
# Accuracy Score: Bayswater -12992.932010415598
# Accuracy Score: Upper Swan -3.8980155949730406
# Accuracy Score: Casuarina -106.1053909208152
# Accuracy Score: Mount Lawley -130.07256661243048
# Accuracy Score: Bickley -7.018304477214603
# Accuracy Score: Mardella -92.06233430567788
# Accuracy Score: Warnbro -5.160380458947046
# Accuracy Score: Parkwood -15.28795382999693
# Accuracy Score: Jandakot 0.652025396934778
# Accuracy Score: Redcliffe -1.010919575170227
# Accuracy Score: Salter Point -25.327538618294582
# Accuracy Score: North Beach 0.5979474773627413
# Accuracy Score: Wilson -599.4668243473232
# Accuracy Score: Wandi -41.39568518604841
# Accuracy Score: Scarborough 0.404278180328274
# Accuracy Score: Karnup -4.4039520405329515
# Accuracy Score: Forrestdale -2.4706949788927983
# Accuracy Score: Hazelmere -75.99262726115026
# Accuracy Score: South Guildford -0.6324985898133952
# Accuracy Score: Greenwood 0.522030969662771
# Accuracy Score: Connolly 0.08372822152123127
# Accuracy Score: Joondalup 0.9857736248619221
# Accuracy Score: Middle Swan -16.021543863463688
# Accuracy Score: Golden Bay -10.262150885474954
# Accuracy Score: Midvale -155.78916545640556
# Accuracy Score: Wembley Downs -0.8522600697309206
# Accuracy Score: Maddington -1.3345793715557828
# Accuracy Score: Beckenham -3.394339750507693
# Accuracy Score: Lathlain -3.6073368268727677
# Accuracy Score: Balcatta 0.31032837227230314
# Accuracy Score: Walliston -9.11374354130756
# Accuracy Score: Orange Grove -6.153238414673619
# Accuracy Score: Manning -9.568706620445733
# Accuracy Score: White Gum Valley 0.6862016550170995
# Accuracy Score: Shelley -7.950390678065515
# Accuracy Score: Bentley -1.0245215570091486
# Accuracy Score: South Perth -0.7578397372976455
# Accuracy Score: Woodbridge -18.942352650972285
# Accuracy Score: Carmel 0.8004841967392452
# Accuracy Score: Carramar 0.11813690354256956
# Accuracy Score: Wattle Grove -0.33399002056110194
# Accuracy Score: Bennett Springs -0.12233935199920976
# Accuracy Score: Forrestfield 0.7257245274229683
# Accuracy Score: Mount Pleasant -0.6797565143649271
# Accuracy Score: Rossmoyne -1973.904638983957
# Accuracy Score: Beaconsfield -14.407323319559067
# Accuracy Score: Menora -2.378687104906188
# Accuracy Score: Maylands 0.844941450616562
# Accuracy Score: Tuart Hill -1.5682440664470847
# Accuracy Score: Glendalough -134.46447053886527
# Accuracy Score: Highgate -21.148134121051882
# Accuracy Score: West Swan -45.38450737642403
# Accuracy Score: Belhus -418.2520209532094

# %%
# empty dictionary for r2 scores
temp = {}

# iterate through recombined dataframe to attain the r2 score for each suburb
for SUBURB in combined_df['SUBURB'].unique():
    sales_slice = combined_df[combined_df['SUBURB'] == SUBURB]
    #df = sales_slice.copy()
    price = sales_slice['PRICE']
    print('Accuracy Score:', SUBURB, r2_score(price, sales_slice['Prediction']))
    temp[SUBURB] = r2_score(price, sales_slice['Prediction'])

# convert r2 dictionary to dataframe
temp = pd.DataFrame.from_dict(temp, orient ='index').reset_index()
temp.head()
# Out:
# Accuracy Score: Butler 0.7442912287744253
# Accuracy Score: Alkimos 0.6408411126955679
# Accuracy Score: Banksia Grove 0.7358804626508805
# Accuracy Score: Pearsall 0.7306469304053844
# Accuracy Score: Harrisdale 0.8017784049682389
# Accuracy Score: Shenton Park 0.7304788334768334
# Accuracy Score: Bertram 0.6068838116946744
# Accuracy Score: Aveley 0.7638809941724093
# Accuracy Score: Redcliffe 0.4491746096803467
# Accuracy Score: North Fremantle -13.739752122500985
# Accuracy Score: Queens Park 0.6969918920981267
# Accuracy Score: Eglinton -6.437628653719629
# Accuracy Score: West Leederville 0.6909078948106073
# Accuracy Score: Inglewood 0.8362437419949704
# Accuracy Score: Clarkson 0.7046989076725676
# Accuracy Score: South Fremantle 0.7256993657261297
# Accuracy Score: Wandi 0.5949253376438116
# Accuracy Score: Innaloo 0.6521398935796696
# Accuracy Score: Ascot 0.4514703971962064
# Accuracy Score: Joondanna 0.5537558037387602
# Accuracy Score: Ridgewood 0.34229136732378584
# Accuracy Score: Cannington -0.5332306437640641
# Accuracy Score: Beaconsfield 0.3308359768522223
# Accuracy Score: Mount Claremont 0.755311267677363
# Accuracy Score: Subiaco 0.8832619636418235
# Accuracy Score: Bentley 0.6572344275316342
# Accuracy Score: Dayton 0.7702348996030913
# Accuracy Score: Fremantle 0.7400525532554609
# Accuracy Score: Yanchep 0.7667061668432725
# Accuracy Score: Doubleview 0.7583717271819683
# Accuracy Score: Embleton 0.5596222886895919
# Accuracy Score: East Victoria Park 0.7121349385870115
# Accuracy Score: North Perth 0.4682702398705578
# Accuracy Score: Ellenbrook 0.7680167495720013
# Accuracy Score: Churchlands -0.5114703529453275
# Accuracy Score: Swanbourne 0.6018857990463926
# Accuracy Score: Stirling 0.6936153119184062
# Accuracy Score: Brentwood 0.8792760577952317
# Accuracy Score: White Gum Valley 0.5870787445052612
# Accuracy Score: Ardross 0.5646660115500524
# Accuracy Score: Madeley 0.7070447706185877
# Accuracy Score: Mount Hawthorn 0.6831093394541177
# Accuracy Score: East Cannington 0.5003380706581997
# Accuracy Score: Jindalee 0.7170603863030657
# Accuracy Score: Carlisle 0.5922716503143666
# Accuracy Score: Yokine 0.8111912716075252
# Accuracy Score: Karrinyup 0.7198039743102764
# Accuracy Score: Sinagra 0.44662953451978216
# Accuracy Score: North Beach 0.7970507769398738
# Accuracy Score: Darch 0.4946756802452559
# Accuracy Score: Maylands 0.830180201872976
# Accuracy Score: Brabham 0.7827616168181247
# Accuracy Score: Victoria Park 0.7031509722022042
# Accuracy Score: Claremont 0.756356774666127
# Accuracy Score: Scarborough 0.41043818173336466
# Accuracy Score: Hilbert -9.600388217784598
# Accuracy Score: Gwelup 0.7448295033800021
# Accuracy Score: Aubin Grove 0.6591855491666678
# Accuracy Score: Caversham 0.7413275131065661
# Accuracy Score: Atwell 0.7264802524712485
# Accuracy Score: Kewdale 0.784826613595571
# Accuracy Score: Mosman Park 0.6873176875922848
# Accuracy Score: Mindarie 0.6239776432148607
# Accuracy Score: Piara Waters 0.8195148569220763
# Accuracy Score: Alfred Cove 0.3517133399651762
# Accuracy Score: North Coogee -6.164290128229791
# Accuracy Score: Melville 0.755481240124248
# Accuracy Score: Currambine 0.6236802815911102
# Accuracy Score: Bayswater -16.566719348733432
# Accuracy Score: Lockridge 0.07096401604832137
# Accuracy Score: Riverton 0.6033984712915549
# Accuracy Score: Balga 0.35217854345514754
# Accuracy Score: Wellard 0.8500735809867093
# Accuracy Score: Bedford 0.5991223024859296
# Accuracy Score: Joondalup 0.8245138802433956
# Accuracy Score: Balcatta 0.8825199914148337
# Accuracy Score: Mount Pleasant 0.6513889512831048
# Accuracy Score: Nollamara 0.8481763266696214
# Accuracy Score: Myaree 0.6994657633414911
# Accuracy Score: Stratton 0.07097745965312163
# Accuracy Score: Tuart Hill 0.7629397096594711
# Accuracy Score: East Fremantle 0.717041455966696
# Accuracy Score: South Guildford 0.6734376121192331
# Accuracy Score: Wattle Grove 0.8451630597415289
# Accuracy Score: St James 0.42476103185690206
# Accuracy Score: Belmont -0.7411711254971762
# Accuracy Score: Landsdale 0.5592360999126358
# Accuracy Score: Highgate 0.7502535021366565
# Accuracy Score: Osborne Park -12.240025969911516
# Accuracy Score: Cottesloe 0.5181964157141694
# Accuracy Score: Mount Lawley 0.26333172207640765
# Accuracy Score: Bassendean 0.7310935772093643
# Accuracy Score: Hilton 0.4636959501704011
# Accuracy Score: Wilson -12.159953428897197
# Accuracy Score: Iluka 0.7093972124462402
# Accuracy Score: Beeliar 0.6508734511922767
# Accuracy Score: Palmyra 0.5310341899762567
# Accuracy Score: Kensington 0.5742315750656297
# Accuracy Score: Ashby 0.3332627628210102
# Accuracy Score: Burswood 0.8514675019495475
# Accuracy Score: Westminster 0.6926190891121282
# Accuracy Score: Guildford 0.6388846647735726
# Accuracy Score: Golden Bay 0.6532793160903749
# Accuracy Score: Southern River 0.7447744212562623
# Accuracy Score: Spearwood 0.7664482627494188
# Accuracy Score: Byford 0.5906133366596027
# Accuracy Score: Lynwood 0.2596063468511782
# Accuracy Score: Coogee 0.7695735293099477
# Accuracy Score: Coolbellup 0.3186247840741201
# Accuracy Score: Manning 0.7217742035480841
# Accuracy Score: Bibra Lake 0.6662650829488281
# Accuracy Score: Shoalwater 0.5487699134250681
# Accuracy Score: Cloverdale 0.5335070286525535
# Accuracy Score: Hillarys 0.7885958466692062
# Accuracy Score: Baldivis 0.7781479748196148
# Accuracy Score: Woodlands 0.09900055095364024
# Accuracy Score: Willagee 0.604223453244721
# Accuracy Score: Hamilton Hill 0.385034958835479
# Accuracy Score: Morley 0.6858687005998575
# Accuracy Score: Champion Lakes 0.5173602417976191
# Accuracy Score: Midland 0.4765811110222764
# Accuracy Score: Hammond Park 0.6603206668729783
# Accuracy Score: Attadale 0.7518657517760989
# Accuracy Score: The Vines 0.7226744781884824
# Accuracy Score: Kelmscott 0.8459396620913278
# Accuracy Score: West Perth 0.9250730649574165
# Accuracy Score: Secret Harbour 0.745907062816194
# Accuracy Score: Wembley 0.6647280546214442
# Accuracy Score: Kenwick -0.4453122364974025
# Accuracy Score: Wembley Downs -2.3635850480287237
# Accuracy Score: Applecross 0.5918398552393231
# Accuracy Score: Como 0.6356418096242906
# Accuracy Score: Lathlain 0.0203807500102412
# Accuracy Score: Shelley -4.132219436299794
# Accuracy Score: Tapping 0.5959049506693541
# Accuracy Score: Bicton 0.6448839989095752
# Accuracy Score: Maddington 0.2603963310978692
# Accuracy Score: South Perth 0.6258759409872933
# Accuracy Score: Rockingham 0.017537365496583246
# Accuracy Score: Canning Vale 0.6114781821901343
# Accuracy Score: Helena Valley 0.7084336193958007
# Accuracy Score: South Lake -8.488484943924005
# Accuracy Score: Kallaroo 0.36467400013643947
# Accuracy Score: Leederville -0.2976174052342617
# Accuracy Score: Rivervale 0.5101927210219175
# Accuracy Score: Connolly 0.3989435649985916
# Accuracy Score: Mirrabooka 0.2042042631073383
# Accuracy Score: Brookdale 0.3648163466277653
# Accuracy Score: Crawley 0.5862824930251808
# Accuracy Score: City Beach 0.4213398221260132
# Accuracy Score: Ballajura 0.7250027544395388
# Accuracy Score: Trigg -2.678666446544249
# Accuracy Score: Langford -4.0808145324118135
# Accuracy Score: Salter Point 0.36636802005042846
# Accuracy Score: Orelia 0.04460926526408093
# Accuracy Score: Booragoon 0.5192021575627679
# Accuracy Score: Waikiki 0.6626609196387363
# Accuracy Score: Success 0.3323600227444137
# Accuracy Score: Dianella 0.6001043536347588
# Accuracy Score: Watermans Bay 0.5423556602060327
# Accuracy Score: Murdoch 0.6961533685040682
# Accuracy Score: Burns Beach 0.652620739120022
# Accuracy Score: Gosnells 0.4216398451861013
# Accuracy Score: Armadale 0.09441321319868534
# Accuracy Score: Jandakot 0.7848306104546947
# Accuracy Score: Singleton 0.35408258382103797
# Accuracy Score: Eden Hill 0.6455223584209067
# Accuracy Score: Girrawheen -0.632484725958941
# Accuracy Score: Hocking 0.11106267918801516
# Accuracy Score: Yangebup 0.7100615800726926
# Accuracy Score: Carramar 0.7885691896620175
# Accuracy Score: Floreat 0.5792804273560588
# Accuracy Score: Quinns Rocks 0.8059853441899738
# Accuracy Score: Mount Nasura 0.7296756899031955
# Accuracy Score: Maida Vale 0.7994620793446789
# Accuracy Score: Bennett Springs 0.43456624336284844
# Accuracy Score: Parkwood 0.5056377937416225
# Accuracy Score: Seville Grove 0.3495617612521318
# Accuracy Score: High Wycombe 0.6814787091105952
# Accuracy Score: Forrestfield 0.7865834943787497
# Accuracy Score: Henley Brook 0.9229550396167309
# Accuracy Score: Waterford 0.05045087220044664
# Accuracy Score: Daglish 0.5703251577013704
# Accuracy Score: Middle Swan -0.5107943945269591
# Accuracy Score: Woodbridge 0.5975633187005243
# Accuracy Score: Karnup -0.4522057006188085
# Accuracy Score: Kwinana Town Centre -0.032832291540432657
# Accuracy Score: Nedlands 0.6477836221445775
# Accuracy Score: Kardinya 0.6812355112982429
# Accuracy Score: Port Kennedy 0.6828989963583694
# Accuracy Score: Merriwa 0.1499298089153901
# Accuracy Score: Jane Brook 0.37255533240366223
# Accuracy Score: Huntingdale 0.31180766541250193
# Accuracy Score: Kinross 0.47618516074381534
# Accuracy Score: Warnbro 0.757574684472004
# Accuracy Score: Beldon 0.3468948295031997
# Accuracy Score: Mullaloo 0.640042406081722
# Accuracy Score: Cooloongup 0.387483162285282
# Accuracy Score: Heathridge 0.4843705952066547
# Accuracy Score: Alexander Heights 0.6469800754652322
# Accuracy Score: Hamersley 0.512027475517226
# Accuracy Score: Wanneroo 0.855524351451832
# Accuracy Score: Camillo 0.32186810577261604
# Accuracy Score: Carine 0.66106408229775
# Accuracy Score: Marangaroo 0.5091188159827331
# Accuracy Score: Parmelia 0.3156433343925039
# Accuracy Score: Edgewater 0.5895310560755341
# Accuracy Score: Warwick 0.5684832453590463
# Accuracy Score: Greenwood 0.45626822859685146
# Accuracy Score: Ocean Reef 0.7004074385989751
# Accuracy Score: Ferndale 0.15826335485821486
# Accuracy Score: Beechboro 0.6276060809634254
# Accuracy Score: Safety Bay 0.6673067253754197
# Accuracy Score: Leeming 0.5584306497733342
# Accuracy Score: Sorrento 0.7043543448149966
# Accuracy Score: Noranda 0.30903496050571366
# Accuracy Score: Padbury 0.5441937826647281
# Accuracy Score: Woodvale 0.7126550010829045
# Accuracy Score: Thornlie 0.7479054046054003
# Accuracy Score: Medina 0.4619725179521842
# Accuracy Score: Koondoola 0.1841239456796666
# Accuracy Score: Duncraig 0.6860435063302557
# Accuracy Score: Craigie 0.1194576991675187
# Accuracy Score: Kingsley 0.630365708687707
# Accuracy Score: Bull Creek 0.8050008869951859
# Accuracy Score: Winthrop 0.5395339355919005
# Accuracy Score: Bateman 0.6507276883415372
# Accuracy Score: Swan View 0.833335057397161
# Accuracy Score: Two Rocks 0.7922877017188069
# Accuracy Score: Rossmoyne 0.48922808529083806
# Accuracy Score: Willetton 0.6409265959291679
# Accuracy Score: Leda 0.7148078759343544
# Accuracy Score: Hillman 0.347953522627355
# Accuracy Score: Beckenham 0.30838142818440684
# Accuracy Score: Kiara 0.2228580645902941
# Accuracy Score: Marmion 0.5949187085146685
# Accuracy Score: Samson 0.4907996933491925
# Accuracy Score: Bullsbrook 0.085082566514873
# Accuracy Score: Menora 0.6434998139933064
# Accuracy Score: Bellevue 0.27146186202118217
# Accuracy Score: Karawara 0.7500820800965644
# Accuracy Score: Ashfield 0.6494158055439283
# Accuracy Score: Calista 0.2862146517930708
# Accuracy Score: Coolbinia 0.7246642771145461
# Accuracy Score: North Lake 0.178973102338726
# Accuracy Score: Greenmount 0.6598291252651236
# Accuracy Score: Koongamia -0.26048661044635146
# Accuracy Score: Midvale -20.136112555447095
# Accuracy Score: Dalkeith -0.3128359559686744
# Accuracy Score: Jolimont 0.556469114100772
# Accuracy Score: Mundijong 0.4805188403134234
# Accuracy Score: Mount Richon 0.8083459248046589
# Accuracy Score: Viveash 0.7306587989550622
# Accuracy Score: Lesmurdie 0.7523075638033696
# Accuracy Score: Cockburn Central -4.0093923003728404
# Accuracy Score: Herne Hill 0.7160764520482886
# Accuracy Score: Jarrahdale 0.8794885066638444
# Accuracy Score: Peppermint Grove 0.9062819617006577
# Accuracy Score: Kalamunda 0.6849823320626574
# Accuracy Score: Darlington 0.4549625581020986
# Accuracy Score: Roleystone 0.6161717664869233
# Accuracy Score: Mount Helena 0.5866911847187954
# Accuracy Score: Gooseberry Hill 0.4861292701888297
# Accuracy Score: Mundaring 0.42318167484000413
# Accuracy Score: Bedfordale 0.5272169069695396
# Accuracy Score: Stoneville 0.7232184564431066
# Accuracy Score: Glen Forrest 0.5519709642782153
# Accuracy Score: Parkerville 0.7797627447470191
# Accuracy Score: Serpentine 0.6565908697888604
# Accuracy Score: Gidgegannup 0.5946370704136564
# Accuracy Score: Oakford 0.29029419615578445
# Accuracy Score: Chidlow 0.6954325787023738
# Accuracy Score: Darling Downs 0.25958514379635544
# Accuracy Score: Boya 0.6506306368949266
# Accuracy Score: Cardup 0.6999605970790966
# Accuracy Score: Sawyers Valley 0.627009724467756
# Accuracy Score: Brigadoon 0.5038967012266886
# Accuracy Score: Banjup 0.3404899694958219
# Accuracy Score: Mahogany Creek 0.6098478189630517
# Accuracy Score: Martin 0.2550395942574374
# Accuracy Score: Hovea -3.303419375771072
# Accuracy Score: Gnangara 0.8322557366353077
# Accuracy Score: Mariginiup -0.3501752300669436
# Accuracy Score: Wooroloo -0.3511979217572545
# Accuracy Score: Upper Swan 0.6368102267111332
# Accuracy Score: Casuarina -6.768002884926857
# Accuracy Score: Bickley -2.2009662245325403
# Accuracy Score: Mardella -60.14237296539653
# Accuracy Score: Forrestdale -0.03961573439480914
# Accuracy Score: Hazelmere -0.6515683767175966
# Accuracy Score: Walliston 0.12651291811865517
# Accuracy Score: Orange Grove -0.5918425774949041
# Accuracy Score: Carmel 0.9596198895189937
# Accuracy Score: Glendalough -8.00798599756944
# Accuracy Score: West Swan 0.3875294029064559
# Accuracy Score: Belhus 0.5036378208031245
#            index         0
# 0         Butler  0.744291
# 1        Alkimos  0.640841
# 2  Banksia Grove  0.735880
# 3       Pearsall  0.730647
# 4     Harrisdale  0.801778

# %%
# rename columns for merging
temp.columns = ['SUBURB', 'r2 Score']
temp.head()
# Out:
#           SUBURB  r2 Score
# 0         Butler  0.744291
# 1        Alkimos  0.640841
# 2  Banksia Grove  0.735880
# 3       Pearsall  0.730647
# 4     Harrisdale  0.801778

# %%
# merge r2 Score onto recombined dataframe
sales_df_r2 = pd.merge(combined_df.reset_index(), temp, how='left', on=['SUBURB', 'SUBURB']).set_index('index')
sales_df_r2.head(2)
# Out:
#                        SUBURB   PRICE BEDROOMS BATHROOMS GARAGE LAND_AREA  \
# index
# 32 Langport Way        Butler  339000        3         2      2       362
# 3 Landbeach Boulevard  Butler  390000        3         2      2       365
#
#                       FLOOR_AREA BUILD_YEAR CBD_DIST     NEAREST_STN  \
# index
# 32 Langport Way              144       2013    36000  Butler Station
# 3 Landbeach Boulevard        146       2008    36900  Butler Station
#
#                       NEAREST_STN_DIST   DATE_SOLD POSTCODE   LATITUDE  \
# index
# 32 Langport Way                   2500   9/01/2018     6036 -31.651509
# 3 Landbeach Boulevard             1400  10/01/2018     6036 -31.646096
#
#                         LONGITUDE                       NEAREST_SCH  \
# index
# 32 Langport Way        115.718454  IRENE MCCORMACK CATHOLIC COLLEGE
# 3 Landbeach Boulevard  115.708062                    BUTLER COLLEGE
#
#                        NEAREST_SCH_DIST  NEAREST_SCH_RANK     Prediction  \
# index
# 32 Langport Way                0.898715             120.0  336522.181670
# 3 Landbeach Boulevard          0.622269              39.0  311312.773832
#
#                        r2 Score
# index
# 32 Langport Way        0.744291
# 3 Landbeach Boulevard  0.744291

# %%
# create a dataframe from the counts of properties per suburb
counts_df = combined_df['SUBURB'].value_counts().rename_axis('SUBURB').reset_index(name='property_count')
counts_df
# Out:
#                   SUBURB  property_count
# 0                Bertram             231
# 1                  Iluka             212
# 2               Carramar             208
# 3                 Butler             207
# 4               Mindarie             202
# ..                   ...             ...
# 291               Carmel               9
# 292            West Swan               8
# 293          Glendalough               8
# 294               Belhus               8
# 295  Kwinana Town Centre               8
#
# [296 rows x 2 columns]

# %%
# add the property count to the r2 score dataframe
temp2 = pd.merge(temp, counts_df, how='left', on=['SUBURB', 'SUBURB'])
temp2
# Out:
#             SUBURB  r2 Score  property_count
# 0           Butler  0.744291             207
# 1          Alkimos  0.640841             114
# 2    Banksia Grove  0.735880             165
# 3         Pearsall  0.730647             145
# 4       Harrisdale  0.801778             147
# ..             ...       ...             ...
# 291   Orange Grove -0.591843              10
# 292         Carmel  0.959620               9
# 293    Glendalough -8.007986               8
# 294      West Swan  0.387529               8
# 295         Belhus  0.503638               8
#
# [296 rows x 3 columns]

# %%
# write the r2 score/property count dataframe to csv
temp2.to_csv('suburb_r2_land_size_date_count.csv', sep=',')
