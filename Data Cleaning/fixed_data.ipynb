# %%
import pandas as pd

# %%
housing_data = pd.read_csv("all_perth_310121.csv")
housing_data
# Out:
#                   ADDRESS           SUBURB    PRICE  BEDROOMS  BATHROOMS  \
# 0           1 Acorn Place       South Lake   565000         4          2
# 1             1 Addis Way            Wandi   365000         3          2
# 2         1 Ainsley Court          Camillo   287000         3          1
# 3         1 Albert Street         Bellevue   255000         2          1
# 4            1 Aman Place        Lockridge   325000         4          1
# ...                   ...              ...      ...       ...        ...
# 33651      9C Gold Street  South Fremantle  1040000         4          3
# 33652      9C Pycombe Way      Westminster   410000         3          2
# 33653      9D Pycombe Way      Westminster   427000         3          2
# 33654     9D Shalford Way       Girrawheen   295000         3          1
# 33655  9E Margaret Street          Midland   295000         3          1
#
#        GARAGE  LAND_AREA  FLOOR_AREA  BUILD_YEAR  CBD_DIST  \
# ...

# %%
sorted_df = housing_data.sort_values(by='BUILD_YEAR', ascending=False)

# Print the sorted DataFrame
sorted_df
# Out:
#                       ADDRESS       SUBURB   PRICE  BEDROOMS  BATHROOMS  \
# 32409     9 Covenham Crescent       Aveley  430000         4          2
# 26971  6 La Fayette Boulevard   Bibra Lake  565000         4          2
# 145         1 Eastfield Court     Ferndale  250000         3          1
# 9209    183A Salisbury Street      Bedford  690000         4          2
# 10148       2 Barnsley Street  Queens Park  480000         4          2
# ...                       ...          ...     ...       ...        ...
# 33630        9a Sydenham Road   Doubleview  990000         4          2
# 33641     9B Leichardt Street     St James  495000         5          1
# 33652          9C Pycombe Way  Westminster  410000         3          2
# 33653          9D Pycombe Way  Westminster  427000         3          2
# 33655      9E Margaret Street      Midland  295000         3          1
#
#        GARAGE  LAND_AREA  FLOOR_AREA  BUILD_YEAR  CBD_DIST  \
# ...

# %%
null_count = sorted_df["BUILD_YEAR"].isnull().sum()
null_count
# Out:
# 3155

# %%
for i in range(len(sorted_df['BUILD_YEAR'])):
    if pd.isnull(sorted_df.loc[i, 'BUILD_YEAR']):
        sorted_df.loc[i, 'BUILD_YEAR'] = sorted_df.loc[i-1, 'BUILD_YEAR']

# %%
for i in range(len(sorted_df['GARAGE'])):
    if pd.isnull(sorted_df.loc[i, 'GARAGE']):
        sorted_df.loc[i, 'GARAGE'] = 0

# %%
sorted_df.reset_index(drop=True)
# Out:
#                       ADDRESS       SUBURB   PRICE  BEDROOMS  BATHROOMS  \
# 0         9 Covenham Crescent       Aveley  430000         4          2
# 1      6 La Fayette Boulevard   Bibra Lake  565000         4          2
# 2           1 Eastfield Court     Ferndale  250000         3          1
# 3       183A Salisbury Street      Bedford  690000         4          2
# 4           2 Barnsley Street  Queens Park  480000         4          2
# ...                       ...          ...     ...       ...        ...
# 33651        9a Sydenham Road   Doubleview  990000         4          2
# 33652     9B Leichardt Street     St James  495000         5          1
# 33653          9C Pycombe Way  Westminster  410000         3          2
# 33654          9D Pycombe Way  Westminster  427000         3          2
# 33655      9E Margaret Street      Midland  295000         3          1
#
#        GARAGE  LAND_AREA  FLOOR_AREA  BUILD_YEAR  CBD_DIST  \
# ...

# %%
sorted_df.to_csv('Perth_Housing_Prices(Fixed).csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_172\1644328402.py in <module>
# ----> 1 sorted_df.to_csv('Perth_Housing_Prices(Fixed).csv')
#
# c:\Users\weima\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3549         )
#    3550
# -> 3551         return DataFrameRenderer(formatter).to_csv(
#    3552             path_or_buf,
#    3553             line_terminator=line_terminator,
#
# ...

# %%
final_sorted.describe()
# Out:
#               PRICE      BEDROOMS     BATHROOMS        GARAGE      LAND_AREA  \
# count  3.365600e+04  33656.000000  33656.000000  33656.000000   33656.000000
# mean   6.370720e+05      3.659110      1.823063      2.037943    2740.644016
# std    3.558256e+05      0.752038      0.587427      1.434123   16693.513215
# min    5.100000e+04      1.000000      1.000000      0.000000      61.000000
# 25%    4.100000e+05      3.000000      1.000000      2.000000     503.000000
# 50%    5.355000e+05      4.000000      2.000000      2.000000     682.000000
# 75%    7.600000e+05      4.000000      2.000000      2.000000     838.000000
# max    2.440000e+06     10.000000     16.000000     99.000000  999999.000000
#
#          FLOOR_AREA    BUILD_YEAR      CBD_DIST  NEAREST_STN_DIST  \
# count  33656.000000  33656.000000  33656.000000      33656.000000
# mean     183.501545   1989.621078  19777.374465       4523.371494
# std       72.102982     21.044630  11364.415413       4495.064024
# ...

# %%
sorted_df.to_csv('Perth_Housing_Prices(Fixed).csv')
